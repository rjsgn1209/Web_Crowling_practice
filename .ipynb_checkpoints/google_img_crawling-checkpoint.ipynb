# %%
# 구글 홈페이지에서 검색어를 입력한 후 구글의 이미지를 크롤링하기...

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from bs4 import BeautifulSoup
from urllib import request
from PIL import Image
from io import BytesIO

# %%
driver = webdriver.Chrome()

# %%
driver.get("https://google.com")

# %%
elem = driver.find_element_by_class_name("gLFyf")
elem.send_keys("새")
elem.send_keys(Keys.RETURN)
# Out:
# C:\Users\bitcamp\AppData\Local\Temp/ipykernel_17248/113480366.py:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   elem = driver.find_element_by_class_name("gLFyf")

# %%
elem = driver.find_element_by_xpath("//*[@id='hdtb-msb']/div[1]/div/div[2]/a")
elem.click()
# Out:
# C:\Users\bitcamp\AppData\Local\Temp/ipykernel_17248/539167571.py:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   elem = driver.find_element_by_xpath("//*[@id='hdtb-msb']/div[1]/div/div[2]/a")

# %%
html = driver.page_source
soup = BeautifulSoup(html, "html.parser")
items = soup.select("a.wXeWr.islib")
for item in items:
    img_url = item.select("img")[0]["src"]
    print("\n" * 5)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17248/1681334132.py in <module>
#       3 items = soup.select("a.wXeWr.islib")
#       4 for item in items:
# ----> 5     img_url = item.select("img")[0]["src"]
#       6     print("\n" * 5)
#       7     res = request.urlopen(img_url).read()
#
# ~\anaconda3\lib\site-packages\bs4\element.py in __getitem__(self, key)
#    1484         """tag[key] returns the value of the 'key' attribute for the Tag,
#    1485         and throws an exception if it's not there."""
# -> 1486         return self.attrs[key]
#    1487
#    1488     def __iter__(self):
#
# KeyError: 'src'

# %%
images = driver.find_elements_by_class_name("wXeWr")
# Out:
# C:\Users\bitcamp\AppData\Local\Temp/ipykernel_17248/2971102405.py:1: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   images = driver.find_elements_by_class_name("wXeWr")

# %%
import time

# %%
for image in images:
    image.click()
    time.sleep(2)
    html = driver.page_source
    soup = BeautifulSoup(html, "html.parser")
    a = soup.select("a.eHAdSb")[0]
    img = a.select("img")[0]["src"]
    print(img)
# Out:
# https://www.sciencetimes.co.kr/wp-content/uploads/2019/11/217880_web.jpg
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRQxYgH3UKnqfUQjM7qzmcCxf05UUJA9wf6jQ&usqp=CAU
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTa7niTH_Ir8bq4N6naXJrkug7_kpV0jcbsug&usqp=CAU
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcS5NHVNOB0v2345x-kKYzImEB7TfaUB_1_97A&usqp=CAU
# ...

# %%
# 스크롤을 끝까지 내리는 코드
import time
SCROLL_PAUSE_TIME = 2
last_height = driver.execute_script("return document.body.scrolHeight")

while True:
    driver.execute_script('window.scrollTo(0, document.body.scrollHeight);')
    time.sleep(SCROLL_PAUSE_TIME)
    
    new_height = driver.execute_script('return document.body.scrolHeight')
    if new_height == last_height:
        try:
            driver.find_element_by_css_selector(".mye4qd").click()
        except:
            break
    last_night = new_height
